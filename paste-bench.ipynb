# %%
"""
64B RPC

l-1c-1conn
root@c307:~# wrk -d 3 -c 1 -t 1 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  1 threads and 1 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency    29.49us    1.84us 259.00us   98.85%
    Req/Sec    32.68k   253.05    33.04k    83.87%
  Latency Distribution
     50%   29.00us
     75%   30.00us
     90%   30.00us
     99%   32.00us
  100763 requests in 3.10s, 14.51MB read
Requests/sec:  32504.21
Transfer/sec:      4.68MB

p-1c-1conn
root@c307:~# wrk -d 3 -c 1 -t 1 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  1 threads and 1 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency    24.12us    1.91us 259.00us   99.14%
    Req/Sec    39.93k   284.36    40.32k    74.19%
  Latency Distribution
     50%   24.00us
     75%   24.00us
     90%   25.00us
     99%   26.00us
  123013 requests in 3.10s, 17.71MB read
Requests/sec:  39691.69
Transfer/sec:      5.72MB

l-1c-50conn
root@c307:~# wrk -d 3 -c 50 -t 50 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  50 threads and 50 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   140.31us   12.77us   0.89ms   77.16%
    Req/Sec     7.08k   138.27     8.78k    95.74%
  Latency Distribution
     50%  140.00us
     75%  147.00us
     90%  155.00us
     99%  172.00us
  1090904 requests in 3.10s, 157.10MB read
Requests/sec: 351931.65
Transfer/sec:     50.68MB

p-1c-50conn
root@c307:~# wrk -d 3 -c 50 -t 50 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  50 threads and 50 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency    94.59us   17.46us   1.14ms   70.83%
    Req/Sec    10.48k   204.22    12.35k    88.97%
  Latency Distribution
     50%   93.00us
     75%  105.00us
     90%  118.00us
     99%  140.00us
  1616290 requests in 3.10s, 232.75MB read
Requests/sec: 521441.06
Transfer/sec:     75.09MB

l-4c-50conn
root@c307:~# wrk -d 3 -c 200 -t 200 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  200 threads and 200 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   177.83us   61.55us   4.78ms   78.44%
    Req/Sec     5.61k     0.98k   11.02k    71.49%
  Latency Distribution
     50%  162.00us
     75%  178.00us
     90%  288.00us
     99%  346.00us
  3460188 requests in 3.10s, 498.28MB read
Requests/sec: 1116467.35
Transfer/sec:    160.78MB

p-4c-50conn
root@c307:~# wrk -d 3 -c 200 -t 200 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  200 threads and 200 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   114.00us  143.92us  18.92ms   97.99%
    Req/Sec     9.25k     1.74k   21.21k    87.14%
  Latency Distribution
     50%   99.00us
     75%  119.00us
     90%  160.00us
     99%  318.00us
  5700369 requests in 3.10s, 820.88MB read
Requests/sec: 1838787.78
Transfer/sec:    264.79MB

l-1c-100conn
root@c307:~# wrk -d 3 -c 100 -t 100 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  100 threads and 100 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   286.43us  119.24us   5.96ms   99.01%
    Req/Sec     3.53k   145.73     5.81k    96.06%
  Latency Distribution
     50%  284.00us
     75%  293.00us
     90%  303.00us
     99%  322.00us
  1088041 requests in 3.10s, 156.68MB read
Requests/sec: 351019.13
Transfer/sec:     50.55MB

p-1c-100conn
root@c307:~# wrk -d 3 -c 100 -t 100 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  100 threads and 100 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   178.74us   23.47us   1.15ms   80.79%
    Req/Sec     5.58k   237.50     8.63k    95.52%
  Latency Distribution
     50%  177.00us
     75%  187.00us
     90%  205.00us
     99%  249.00us
  1721595 requests in 3.10s, 247.92MB read
Requests/sec: 555360.21
Transfer/sec:     79.97MB

l-4c-100conn
root@c307:~# wrk -d 3 -c 400 -t 400 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  400 threads and 400 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   377.79us  451.67us  14.78ms   99.05%
    Req/Sec     2.81k   833.94    12.23k    83.28%
  Latency Distribution
     50%  366.00us
     75%  458.00us
     90%  479.00us
     99%  782.00us
  3462344 requests in 3.10s, 498.59MB read
Requests/sec: 1116785.73
Transfer/sec:    160.82MB

p-4c-100conn
root@c307:~# wrk -d 3 -c 400 -t 400 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  400 threads and 400 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency
http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  1 threads and 1 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency    32.27us    4.89us  92.00us   63.79%
    Req/Sec    29.96k     0.94k   31.32k    70.97%
  Latency Distribution
     50%   33.00us
     75%   36.00us
     90%   38.00us
     99%   43.00us
  92413 requests in 3.10s, 13.31MB read
Requests/sec:  29812.38
Transfer/sec:      4.29MB

f-1c-50conn
root@c307:~# wrk -d 3 -c 50 -t 50 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  50 threads and 50 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   225.98us   75.60us   1.92ms   78.98%
    Req/Sec     4.42k   758.58     6.03k    46.71%
  Latency Distribution
     50%  195.00us
     75%  207.00us
     90%  377.00us
     99%  401.00us
  681282 requests in 3.10s, 98.11MB read
Requests/sec: 219790.93
Transfer/sec:     31.65MB

p-1c-50conn
intr=1000
root@c307:~# wrk -d 3 -c 50 -t 50 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  50 threads and 50 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   119.28us   60.65us   1.98ms   97.61%
    Req/Sec     8.64k   188.11     9.95k    80.39%
  Latency Distribution
     50%  111.00us
     75%  123.00us
     90%  141.00us
     99%  355.00us
  1331786 requests in 3.10s, 191.78MB read
Requests/sec: 429678.66
Transfer/sec:     61.88MB


f-1c-100conn
intr 31250
root@c307:~# wrk -d 3 -c 100 -t 100 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  100 threads and 100 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   448.25us  113.57us   3.89ms   91.45%
    Req/Sec     2.23k   321.09     3.97k    79.57%
  Latency Distribution
     50%  424.00us
     75%  430.00us
     90%  444.00us
     99%    0.86ms
  687804 requests in 3.10s, 99.05MB read
Requests/sec: 221920.29
Transfer/sec:     31.96MB

p-1c-100conn
root@c307:~# wrk -d 3 -c 100 -t 100 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  100 threads and 100 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   231.62us  100.71us   4.15ms   95.71%
    Req/Sec     4.46k   223.62     7.01k    95.00%
  Latency Distribution
     50%  217.00us
     75%  229.00us
     90%  252.00us
     99%  723.00us
  1374349 requests in 3.10s, 197.91MB read
Requests/sec: 443348.97
Transfer/sec:     63.84MB


f-4c-50conn
root@c307:~# wrk -d 3 -c 200 -t 200 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  200 threads and 200 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency     7.37ms   29.15ms 229.88ms   94.98%
    Req/Sec     2.79k     1.35k   11.79k    84.49%
  Latency Distribution
     50%  318.00us
     75%  459.00us
     90%    9.38ms
     99%  182.25ms
  1684870 requests in 3.10s, 242.63MB read
Requests/sec: 543580.62
Transfer/sec:     78.28MB

p-4c-50conn
intr=31250
root@c307:~# wrk -d 3 -c 200 -t 200 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  200 threads and 200 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   242.73us  156.40us   4.11ms   92.75%
    Req/Sec     4.39k   480.47     8.94k    89.69%
  Latency Distribution
     50%  212.00us
     75%  245.00us
     90%  316.00us
     99%    0.98ms
  2561718 requests in 3.10s, 368.90MB read
Requests/sec: 826348.12
Transfer/sec:    119.00MB

f-4c-100conn
intr=31250
root@c307:~# wrk -d 3 -c 400 -t 400 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  400 threads and 400 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   136.45ms  306.04ms   1.29s    86.29%
    Req/Sec     1.87k     1.48k    5.43k    73.57%
  Latency Distribution
     50%  501.00us
     75%   27.30ms
     90%  664.20ms
     99%    1.20s 
  1656471 requests in 3.10s, 238.54MB read
Requests/sec: 534440.13
Transfer/sec:     76.96MB

p-4c-100conn
root@c307:~# wrk -d 3 -c 400 -t 400 http://192.168.11.3:60000/ --latency
Running 3s test @ http://192.168.11.3:60000/
  400 threads and 400 connections
  Thread Stats   Avg      Stdev     Max   +/- Stdev
    Latency   460.19us  208.93us   6.38ms   88.86%
    Req/Sec     2.24k   359.64     6.92k    94.18%
  Latency Distribution
     50%  421.00us
     75%  477.00us
     90%  607.00us
     99%    1.37ms
  2624981 requests in 3.10s, 378.01MB read
Requests/sec: 846811.50
Transfer/sec:    121.94MB

"""

# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

#plt.rc('text', usetex=True)
#plt.rc('font', family='times')


layout = [1, 2, 4, 5, 6, 7, 9, 10, 11, 12]
xlabel = ['1 conn.\n1 core', '',
          '50 conn.\n1 core','','50 conn.\n4 core', '', 
          '100 conn.\n1 core', '', '100 conn.\n4 core', '']
throughput = [32504.21, 39691.69,
              351931.65, 521441.06, 1116467.35, 1838787.78,
              351019.13, 555360.21, 1116785.73, 1917928.12]
tmp = [i/1000 for i in throughput]
throughput = tmp
latency = [29.5, 24.1, 140.3, 94.6, 177.8, 114.0, 286.4, 178.7, 377.8, 217.2]
plt.rcParams.update({'font.size':10})
fig, (ax) = plt.subplots(1, 1)
fig.set_size_inches([7, 2.25]) # half column width
fig.text(0.13, 0.9, 'Number on each bar indicates mean latency (round trip) in us')
fig.text(0.35, -0.2, '64B RPC-like workload', size=12)
ax.set_ylim(0, max(throughput)*1.2)
ax.set_ylabel('Throughput [1K trans/s]')
plt.xticks(layout, xlabel, horizontalalignment='left')
ax.tick_params(axis='x', length=0)

ax.grid(which='major', axis='y', linestyle='--', color='#dddddd', zorder=0)
barwidth = 0.5

color = ['#99ddff', '#00ff7f'] * int(len(layout) / 2)

led = []
for i in range(len(layout)):
    p = ax.bar(layout[i], throughput[i], color=color[i], zorder=8)
    plt.text(layout[i]-0.4, throughput[i]+100, latency[i], rotation=0)
    if i < 2: led.append(p)
        
fig.legend(led, ['Linux', 'PASTE'], loc='upper left', bbox_to_anchor=(0.11, 1.1), frameon=False)
fig.savefig('paste-rpc.pdf', bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

#plt.rc('text', usetex=True)
#plt.rc('font', family='times')


layout = [1, 2, 4, 5, 6, 7, 9, 10, 11, 12]
xlabel = ['1 conn.\n1 core', '',
          '50 conn.\n1 core','','50 conn.\n4 core', '', 
          '100 conn.\n1 core', '', '100 conn.\n4 core', '']
throughput = [28095.29, 29812.38,
              219790.93, 429678.66, 543580.62, 826348.12,
              221920.29, 443348.97, 534440.13, 846811.50]
tmp = [i/1000 for i in throughput]
throughput = tmp
latency = [34.26, 32.27, 225.98, 119.28, 7370, 242.73, 448.25, 231.62, 136450, 460.19]
plt.rcParams.update({'font.size':10})
fig, (ax) = plt.subplots(1, 1)
fig.set_size_inches([7, 2.25]) # half column width
fig.text(0.13, 0.9, 'Number on each bar indicates mean latency (round trip) in us')
fig.text(0.35, -0.2, '64B RPC-like workload', size=12)
ax.set_ylim(0, max(throughput)*1.2)
ax.set_ylabel('Throughput [1K trans/s]')
plt.xticks(layout, xlabel, horizontalalignment='left')
ax.tick_params(axis='x', length=0)

ax.grid(which='major', axis='y', linestyle='--', color='#dddddd', zorder=0)
barwidth = 0.5

color = ['#99ddff', '#00ff7f'] * int(len(layout) / 2)

led = []
for i in range(len(layout)):
    p = ax.bar(layout[i], throughput[i], color=color[i], zorder=8)
    plt.text(layout[i]-0.5, throughput[i]+20, latency[i], rotation=0, zorder=9)
    if i < 2: led.append(p)
        
fig.legend(led, ['FreeBSD', 'PASTE'], loc='upper left', bbox_to_anchor=(0.11, 1.1), frameon=False)
fig.savefig('paste-rpc-fbsd.pdf', bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
from collections import OrderedDict
import numpy

#plt.rc('text', usetex=True)
#plt.rc('font', family='times')

layout = [1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13]
label = ['Linux-1conn', 'PasteCopy-1conn', 'Paste-1conn', 
         'Linux-50conn', 'PasteCopy-50conn', 'Paste-50conn',
         'Linux-100conn', 'PasteCopy-100conn', 'Paste-100conn',
         'Linux-1conn-e10k', 'PasteCopy-1conn-e10k', 'Paste-1conn-e10k', 
         'Linux-50conn-e10k', 'PasteCopy-50conn-e10k', 'Paste-50conn-e10k',
         'Linux-100conn-e10k', 'PasteCopy-100conn-e10k', 'Paste-100conn-e10k']
xlabels = ['1 conn.', '', '50 conn.', '', '100 conn.', '', '1 conn.', '', '50 conn.', '', '100 conn.', '']
"""
throughput = [28069.78, 34033.47, 35557.05,
              271404.68, 373522.83, 483073.99,
              21315.05, 24314.40, 24899.29,
              71741.82, 324803.95, 403653.93]
"""
throughput = [28069.78, 35557.05,
              271404.68, 483073.99,
              278319.48, 518149.91,
              21315.05, 24899.29,
              71741.82, 403653.93,
              72151.88, 462108.00]
tmp = [i/1000 for i in throughput]
throughput = tmp
"""
latency = [34.5, 28.4, 27.0,
          183.0, 132.8, 102.2,
          45.46, 39.92, 38.80,
          694.72, 152.41, 122.46]
"""
latency = [34.5, 27.0,
          183.0, 102.2,
          368.63, 191.64,
          45.46, 38.80,
          694.72, 122.46,
          1380.0, 214.99]
tmp = [round(i, 1) for i in latency]
latency = tmp        

plt.rcParams.update({'font.size':10})
fig, (ax) = plt.subplots(1, 1)
fig.set_size_inches([7, 2.25]) # half column width

fig.text(0.2, -0.05, 'DRAM access latency', size=12)
fig.text(0.52, -0.05, 'Emulated 10us access latency', size=12)
fig.text(0.13, 0.9, 'Number on each bar indicates mean latency (round trip) in us')
fig.text(0.35, -0.2, '1KB Write-Ahead Logging', size=12)

ax.set_ylim(0, max(throughput)*1.2)
ax.set_ylabel('Throughput [1K trans/s]')
plt.xticks(layout, xlabels, horizontalalignment='left')
ax.set_yticks(numpy.arange(0, max(throughput)+100, 100))
ax.tick_params(axis='x', length=0)

ax.grid(which='major', axis='y', linestyle='--', color='#dddddd', zorder=0)
barwidth = 0.8

color = ['#99ddff', '#00ff7f'] * int(len(layout) / 2)

led=[]
for i in range(len(layout)):
    p = ax.bar(layout[i], throughput[i], color=color[i], zorder=8)
    s = 0.5
    if latency[i] > 1000: s = 0.6
    plt.text(layout[i]-s, throughput[i]+20, latency[i], rotation=0, zorder=9)
    if i < 2: led.append(p)
fig.legend(led, ['Linux', 'PASTE'], loc='upper left', bbox_to_anchor=(0.1, 1.1), frameon=False)
fig.savefig('paste-wal.pdf', bbox_inches="tight")
